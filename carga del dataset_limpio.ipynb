# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego4390oi43kjripo43/Proyecto_Prueba_2/blob/carlos_contreras/carga%20del%20dataset_limpio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("accidentes_limpios.csv")
df.head()
# Out:
#    ID_ACCIDENTE    ANYO  MES  DIA_SEMANA  HORA  COD_PROVINCIA  COD_MUNICIPIO  \
# 0             1  2024.0  1.0         3.0  22.0            1.0            0.0
# 1             2  2024.0  1.0         6.0  23.0            1.0         1036.0
# 2             3  2024.0  1.0         7.0   1.0            1.0            0.0
# 3             4  2024.0  1.0         7.0   8.0            1.0            0.0
# 4             5  2024.0  1.0         4.0  17.0            1.0            0.0
#
#    ZONA  ZONA_AGRUPADA CARRETERA  ...  CONDICION_METEO  CONDICION_NIEBLA  \
# 0   1.0            1.0    A-2622  ...              1.0               0.0
# 1   1.0            1.0     A-625  ...              4.0               0.0
# 2   1.0            1.0      AP-1  ...              3.0               0.0
# 3   1.0            1.0    A-2522  ...              3.0               0.0
# 4   1.0            1.0    A-3600  ...              2.0               0.0
#
#    ACERA  TRAZADO_PLANTA   ZONA_KM  HAY_NIEBLA  TRAMO_HORA  \
# ...
